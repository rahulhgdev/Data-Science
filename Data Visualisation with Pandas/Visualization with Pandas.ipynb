# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data1 = pd.read_csv('csv/Wellbeing_2020.csv', index_col=0)

# %%
data1.head()
# Out:
#        VaCode  Estimate  ASE Flag
# CACode
# C01T     V00T     100.0  NaN    B
# C01T     V01A      15.9  0.7  NaN
# C01T     V01B      17.6  0.9  NaN
# C01T     V01C      33.5  1.0  NaN
# C01T     V01D      16.2  0.8  NaN

# %%
data1['ASE'].hist(bins = 30, grid= False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Method 1

# %%
data1['Estimate'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Method 2

# %%
data1['Estimate'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## area plot

# %%
df1 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

# %%
df1.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## bar plot

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## hist

# %%
data1.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## scatter

# %%
data1.plot.scatter(x='Estimate', y='ASE', c='red')
# Out:
# <AxesSubplot:xlabel='Estimate', ylabel='ASE'>

# %% [markdown]
# ## line

# %%
data1.plot.line(x='Estimate', y='ASE',cmap='twilight_shifted')
# Out:
# <AxesSubplot:xlabel='Estimate'>

# %% [markdown]
# ## box

# %%
df3 = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])

# %%
df3.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## hex

# %%
df4 = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df4.head()
# Out:
#           a         b
# 0  0.018879 -1.699580
# 1  1.639813 -0.848222
# 2  1.757734 -0.376910
# 3 -0.067839 -1.876535
# 4 -0.339029 -1.158996

# %%
df4.plot.hexbin(x='a',y='b', gridsize=25, cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ## density

# %%
df4['b'].plot.kde()   # kernel density

#
df4['b'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Pandas Visualization is just for quick analsys where as Matplotlib and Seaborn is standard and customizable way i.e we can customize
