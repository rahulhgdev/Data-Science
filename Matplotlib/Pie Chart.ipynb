# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_values = [1400,600,300,420,1053]
exp_labels = ["home","wifi","car","mobile","laptop"]

plt.axis('Equal')
plt.pie(exp_values, labels=exp_labels, radius=2,autopct='%0.2f%%', explode=[0.1,0.1,0.1,0,0])


# to save 

plt.savefig('pie_output.jpg', bbox_inches="tight",pad_inches=2, transparent=True)
