# %%
import numpy as np
import pandas as pd

# %%
# Install these packages

# pip install sqlalchemy
# pip install html5lib
# pip install BequtifulSoup4
# pip install lxml
# pip install xlrd
# pip install openpyxl
# pip install xlwt

# %% [markdown]
# # CSV

# %%
pd.read_csv(r'CSV/Wellbeing_2020.csv')
# Out:
#      CACode VaCode  Estimate  ASE Flag
# 0      C01T   V00T     100.0  NaN    B
# 1      C01T   V01A      15.9  0.7  NaN
# 2      C01T   V01B      17.6  0.9  NaN
# 3      C01T   V01C      33.5  1.0  NaN
# 4      C01T   V01D      16.2  0.8  NaN
# ...     ...    ...       ...  ...  ...
# 5854   C15D   V17C      28.2  4.4  NaN
# 5855   C15D   V17D      34.0  4.8  NaN
# 5856   C15D   V17E      25.4  4.5  NaN
# 5857   C15D   V18A      94.2  2.3  NaN
# 5858   C15D   V18B       5.8  2.3    *
#
# [5859 rows x 5 columns]

# %%
df = pd.read_csv(r'CSV/Wellbeing_2020.csv')

# %%
df
# Out:
#      CACode VaCode  Estimate  ASE Flag
# 0      C01T   V00T     100.0  NaN    B
# 1      C01T   V01A      15.9  0.7  NaN
# 2      C01T   V01B      17.6  0.9  NaN
# 3      C01T   V01C      33.5  1.0  NaN
# 4      C01T   V01D      16.2  0.8  NaN
# ...     ...    ...       ...  ...  ...
# 5854   C15D   V17C      28.2  4.4  NaN
# 5855   C15D   V17D      34.0  4.8  NaN
# 5856   C15D   V17E      25.4  4.5  NaN
# 5857   C15D   V18A      94.2  2.3  NaN
# 5858   C15D   V18B       5.8  2.3    *
#
# [5859 rows x 5 columns]

# %%
df.head()
# Out:
#   CACode VaCode  Estimate  ASE Flag
# 0   C01T   V00T     100.0  NaN    B
# 1   C01T   V01A      15.9  0.7  NaN
# 2   C01T   V01B      17.6  0.9  NaN
# 3   C01T   V01C      33.5  1.0  NaN
# 4   C01T   V01D      16.2  0.8  NaN

# %%
df.tail()
# Out:
#      CACode VaCode  Estimate  ASE Flag
# 5854   C15D   V17C      28.2  4.4  NaN
# 5855   C15D   V17D      34.0  4.8  NaN
# 5856   C15D   V17E      25.4  4.5  NaN
# 5857   C15D   V18A      94.2  2.3  NaN
# 5858   C15D   V18B       5.8  2.3    *

# %% [markdown]
# ### to save

# %%
df.to_csv('CSV/MyOutput.csv')             # index = true(bydefault)

# %%
pd.read_csv('CSV/MyOutput.csv')
# Out:
#       Unnamed: 0 CACode VaCode  Estimate  ASE Flag
# 0              0   C01T   V00T     100.0  NaN    B
# 1              1   C01T   V01A      15.9  0.7  NaN
# 2              2   C01T   V01B      17.6  0.9  NaN
# 3              3   C01T   V01C      33.5  1.0  NaN
# 4              4   C01T   V01D      16.2  0.8  NaN
# ...          ...    ...    ...       ...  ...  ...
# 5854        5854   C15D   V17C      28.2  4.4  NaN
# 5855        5855   C15D   V17D      34.0  4.8  NaN
# 5856        5856   C15D   V17E      25.4  4.5  NaN
# 5857        5857   C15D   V18A      94.2  2.3  NaN
# 5858        5858   C15D   V18B       5.8  2.3    *
#
# [5859 rows x 6 columns]

# %%
df.to_csv('CSV/MyOutput.csv', index = False)   # index = False

# %%
pd.read_csv('CSV/MyOutput.csv')
# Out:
#      CACode VaCode  Estimate  ASE Flag
# 0      C01T   V00T     100.0  NaN    B
# 1      C01T   V01A      15.9  0.7  NaN
# 2      C01T   V01B      17.6  0.9  NaN
# 3      C01T   V01C      33.5  1.0  NaN
# 4      C01T   V01D      16.2  0.8  NaN
# ...     ...    ...       ...  ...  ...
# 5854   C15D   V17C      28.2  4.4  NaN
# 5855   C15D   V17D      34.0  4.8  NaN
# 5856   C15D   V17E      25.4  4.5  NaN
# 5857   C15D   V18A      94.2  2.3  NaN
# 5858   C15D   V18B       5.8  2.3    *
#
# [5859 rows x 5 columns]

# %% [markdown]
# # EXCEL

# %%
pd.read_excel('EXCEL/Sample.xls',sheet_name='Sheet1')
# Out:
#      Unnamed: 0           Segment                   Country    Product  \
# 0             0        Government                    Canada  Carretera
# 1             1        Government                   Germany  Carretera
# 2             2         Midmarket                    France  Carretera
# 3             3         Midmarket                   Germany  Carretera
# 4             4         Midmarket                    Mexico  Carretera
# ..          ...               ...                       ...        ...
# 695         695    Small Business                    France   Amarilla
# 696         696    Small Business                    Mexico   Amarilla
# 697         697        Government                    Mexico    Montana
# 698         698        Government                    Canada      Paseo
# 699         699  Channel Partners  United States of America        VTT
#
#     Discount Band  Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
# ...

# %%
df = pd.read_excel('EXCEL/Sample.xls',sheet_name='Sheet1')
df.head()
# Out:
#    Unnamed: 0     Segment  Country    Product Discount Band  Units Sold  \
# 0           0  Government   Canada  Carretera          None      1618.5
# 1           1  Government  Germany  Carretera          None      1321.0
# 2           2   Midmarket   France  Carretera          None      2178.0
# 3           3   Midmarket  Germany  Carretera          None       888.0
# 4           4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# ...

# %% [markdown]
# ### to save

# %%
df.to_excel('EXCEL/OutputSheet.xls',sheet_name='Sheet1')
# Out:
# <ipython-input-14-79952d06237b>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('EXCEL/OutputSheet.xls',sheet_name='Sheet1')

# %%
pd.read_excel('EXCEL/OutputSheet.xls',sheet_name='Sheet1')
# Out:
#      Unnamed: 0  Unnamed: 0.1           Segment                   Country  \
# 0             0             0        Government                    Canada
# 1             1             1        Government                   Germany
# 2             2             2         Midmarket                    France
# 3             3             3         Midmarket                   Germany
# 4             4             4         Midmarket                    Mexico
# ..          ...           ...               ...                       ...
# 695         695           695    Small Business                    France
# 696         696           696    Small Business                    Mexico
# 697         697           697        Government                    Mexico
# 698         698           698        Government                    Canada
# 699         699           699  Channel Partners  United States of America
#
#        Product Discount Band  Units Sold  Manufacturing Price  Sale Price  \
# ...

# %% [markdown]
# # HTML

# %%
data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
type(data)
# Out:
# list

# %%
data[0].head()
# Out:
#                           Bank Name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#         Acquiring Institution       Closing Date
# 0                 Equity Bank   October 23, 2020
# 1   United Fidelity Bank, fsb   October 16, 2020
# 2              MVB Bank, Inc.      April 3, 2020
# 3  Farmers and Merchants Bank  February 14, 2020
# 4             Industrial Bank   November 1, 2019

# %% [markdown]
# # SQL

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df
# Out:
#      Unnamed: 0           Segment                   Country    Product  \
# 0             0        Government                    Canada  Carretera
# 1             1        Government                   Germany  Carretera
# 2             2         Midmarket                    France  Carretera
# 3             3         Midmarket                   Germany  Carretera
# 4             4         Midmarket                    Mexico  Carretera
# ..          ...               ...                       ...        ...
# 695         695    Small Business                    France   Amarilla
# 696         696    Small Business                    Mexico   Amarilla
# 697         697        Government                    Mexico    Montana
# 698         698        Government                    Canada      Paseo
# 699         699  Channel Partners  United States of America        VTT
#
#     Discount Band  Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
# ...

# %% [markdown]
# ### to save

# %%
df.to_sql('my_sql',engine)

# %%
sqldf = pd.read_sql('my_sql',con=engine)

# %%
sqldf.head()
# Out:
#    index  Unnamed: 0     Segment  Country    Product Discount Band  \
# 0      0           0  Government   Canada  Carretera          None
# 1      1           1  Government  Germany  Carretera          None
# 2      2           2   Midmarket   France  Carretera          None
# 3      3           3   Midmarket  Germany  Carretera          None
# 4      4           4   Midmarket   Mexico  Carretera          None
#
#    Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 0      1618.5                    3          20      32370.0        0.0
# 1      1321.0                    3          20      26420.0        0.0
# 2      2178.0                    3          15      32670.0        0.0
# 3       888.0                    3          15      13320.0        0.0
# 4      2470.0                    3          15      37050.0        0.0
#
#      Sales     COGS   Profit       Date  Month Number Month Name  Year
# ...
