# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Creating Matplotlib plot

# %% [markdown]
# ## Function Method

# %%
x = np.linspace(0,5,11)
y =  x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plot')
# Out:
# Text(0.5, 1.0, 'Plot')

# %% [markdown]
# ## Subplot

# %%
plt.subplot(1,2,1)           #(rows,columns,figure you're working on)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# # Object Oriented Method

# %%
fig = plt.figure()

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])       #([left of the axes, bottom of the axes,width, height])   
                                             #& Each number must be between 0 and 1
axes.plot(x,y,'r-o')
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title Here')
# Out:
# Text(0.5, 1.0, 'Title Here')

# %%
## Another Example

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.set_title('Outer')
axes2.set_title('Inner')

axes1.plot(x,y)
axes2.plot(y,x)

# %%
## Complicated one

# %%
fig = plt.figure(facecolor='cyan')
axes1 = fig.add_axes([0.2,0.1,0.9,0.1])
axes2 = fig.add_axes([0.2,0.2,0.5,0.5])
axes3 = fig.add_axes([0.7,0.2,0.4,0.3])

axes1.set_title('Outer')
axes2.set_title('Inner1')
axes3.set_title('Inner2')

axes2.plot(x,y,'r')
axes3.plot(y,x,'g')
axes1.plot(np.arange(0,5,1))

# %% [markdown]
# ## Subplot

# %%
axes,fig = plt.subplots(nrows=1, ncols=2)

plt.tight_layout()    # for overlaping

#axes.plot(x,y)
